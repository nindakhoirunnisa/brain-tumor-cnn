# %% [markdown]
# ### Import Data

# %%
import zipfile

extract_zip = 'archive (2).zip'
out_zip = zipfile.ZipFile(extract_zip, 'r')
out_zip.extractall('Dataset')
out_zip.close()

print('Success')
# Out:
# Success

# %% [markdown]
# ### Preprocessing

# %%
# !mkdir "raw dataset"

# %%
import shutil
import os

source = "D:\Coursework\Statistics and Machine Learning\Brain tumor\Dataset\Training\glioma_tumor"
destination = "D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor"

files = os.listdir(source)

for file in files:
	new_path = shutil.copy(f"{source}/{file}", destination)
	print(new_path)
# Out:
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\gg (1).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\gg (10).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\gg (100).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\gg (101).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\gg (102).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\gg (103).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\gg (104).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\gg (105).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\gg (106).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\gg (107).jpg
# ...

# %%
source = "D:\Coursework\Statistics and Machine Learning\Brain tumor\Dataset\Testing\glioma_tumor"
destination = "D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor"

files = os.listdir(source)

for file in files:
	new_path = shutil.copy(f"{source}/{file}", destination)
	print(new_path)
# Out:
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\image(1).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\image(10).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\image(100).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\image(11).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\image(12).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\image(13).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\image(14).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\image(15).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\image(16).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/glioma_tumor\image(17).jpg
# ...

# %%
source = "D:\Coursework\Statistics and Machine Learning\Brain tumor\Dataset\Training\meningioma_tumor"
destination = "D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/meningioma_tumor"

files = os.listdir(source)

for file in files:
	new_path = shutil.copy(f"{source}/{file}", destination)
	print(new_path)

source = "D:\Coursework\Statistics and Machine Learning\Brain tumor\Dataset\Testing\meningioma_tumor"
destination = "D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/meningioma_tumor"

files = os.listdir(source)

for file in files:
	new_path = shutil.copy(f"{source}/{file}", destination)
	print(new_path)
# Out:
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/meningioma_tumor\m (10).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/meningioma_tumor\m (100).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/meningioma_tumor\m (101).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/meningioma_tumor\m (102).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/meningioma_tumor\m (103).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/meningioma_tumor\m (104).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/meningioma_tumor\m (105).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/meningioma_tumor\m (106).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/meningioma_tumor\m (107).jpg
# ...

# %%
source = "D:\Coursework\Statistics and Machine Learning\Brain tumor\Dataset\Training\pituitary_tumor"
destination = "D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/pituitary_tumor"

files = os.listdir(source)

for file in files:
	new_path = shutil.copy(f"{source}/{file}", destination)
	print(new_path)

source = "D:\Coursework\Statistics and Machine Learning\Brain tumor\Dataset\Testing\pituitary_tumor"
destination = "D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/pituitary_tumor"

files = os.listdir(source)

for file in files:
	new_path = shutil.copy(f"{source}/{file}", destination)
	print(new_path)
# Out:
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/pituitary_tumor\p (1).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/pituitary_tumor\p (10).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/pituitary_tumor\p (100).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/pituitary_tumor\p (101).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/pituitary_tumor\p (102).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/pituitary_tumor\p (103).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/pituitary_tumor\p (104).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/pituitary_tumor\p (105).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/pituitary_tumor\p (106).jpg
# D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/pituitary_tumor\p (107).jpg
# ...

# %%
# source = "D:\Coursework\Statistics and Machine Learning\Brain tumor\Dataset\Training\no_tumor"
# destination = "D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/no_tumor"

# files = os.listdir(source)

# for file in files:
# 	new_path = shutil.copy(f"{source}/{file}", destination)
# 	print(new_path)

# source = "D:\Coursework\Statistics and Machine Learning\Brain tumor\Dataset\Testing\no_tumor"
# destination = "D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/no_tumor"

# files = os.listdir(source)

# for file in files:
# 	new_path = shutil.copy(f"{source}/{file}", destination)
# 	print(new_path)

# %%
# pip install split-folders
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure(figsize=(16, 12))
h, w = 224, 224

path = 'D:/Coursework/Statistics and Machine Learning/Brain tumor/Dataset/Training/'
fileNames = ['glioma_tumor/gg (10).jpg', 'meningioma_tumor/m (108).jpg', 'no_tumor/image (16).jpg', 'pituitary_tumor/p (12).jpg']
fileLabels = ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']

for i in range(4):
    ax = plt.subplot(4, 4, i + 1)
    img = mpimg.imread(path + fileNames[i])
    img = cv2.resize(img, (h, w))
    plt.imshow(img)
    plt.title(fileLabels[i])
    plt.axis("off")

# %%
import glob
total_image = len(list(glob.iglob("D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset/*/*.jpg*", recursive=True)))
print("Total Dataset Raw    : ",total_image," JPG Image \n")
# Out:
# Total Dataset Raw    :  3264  JPG Image

# %%
# !mkdir "New Dataset"

# %%
import splitfolders
splitfolders.ratio('D:/Coursework/Statistics and Machine Learning/Brain tumor/raw dataset',
                   output='D:/Coursework/Statistics and Machine Learning/Brain tumor/data_new',
                   seed=42,
                   ratio=(.8, .1, .1), group_prefix=None)
# Out:
# Copying files: 3264 files [00:01, 3191.38 files/s]

# %%
total_image = len(list(glob.iglob("D:/Coursework/Statistics and Machine Learning/Brain tumor/data_new/train/*/*.jpg*", recursive=True)))
print("Total Dataset Train    : ",total_image," JPG Image \n")
# Out:
# Total Dataset Train    :  2609  JPG Image

# %%
total_image = len(list(glob.iglob("D:/Coursework/Statistics and Machine Learning/Brain tumor/data_new/val/*/*.jpg*", recursive=True)))
print("Total Dataset Validation    : ",total_image," JPG Image \n")
# Out:
# Total Dataset Validation    :  325  JPG Image

# %%
total_image = len(list(glob.iglob("D:/Coursework/Statistics and Machine Learning/Brain tumor/data_new/test/*/*.jpg*", recursive=True)))
print("Total Dataset Test    : ",total_image," JPG Image \n")
# Out:
# Total Dataset Test    :  330  JPG Image

# %%
# pip install opencv-python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os

# %%
training_dir = r"data_new/train/"
validation_dir = r"data_new/val/"
testing_dir = r"data_new/test"

categories = ["glioma_tumor","meningioma_tumor","no_tumor","pituitary_tumor"]

# %%
img_size = (128, 128)

training_data = []

def create_training_data():
    for category in categories:
        path = os.path.join(training_dir,category)
        class_num = categories.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img))
                new_array = cv2.resize(img_array, img_size)
                training_data.append([new_array, class_num])
            except Exception as e:
                pass

create_training_data()
print("Training Data is created")
# Out:
# Training Data is created

# %%
validation_data = []

def create_val_data():
    for category in categories:
        path = os.path.join(validation_dir,category)
        class_num = categories.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img))
                new_array = cv2.resize(img_array, img_size)
                validation_data.append([new_array, class_num])
            except Exception as e:
                pass

create_val_data()
print("Validation Data is created")
# Out:
# Validation Data is created

# %%
testing_data = []

def create_test_data():
    for category in categories:
        path = os.path.join(testing_dir,category)
        class_num = categories.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img))
                new_array = cv2.resize(img_array, img_size)
                testing_data.append([new_array, class_num])
            except Exception as e:
                pass

create_test_data()
print("Testing Data is created")
# Out:
# Testing Data is created

# %%
X_train = []
y_train = []

for features, label in training_data:
    X_train.append(features)
    y_train.append(label)

X_train = np.array(X_train).reshape(-1,128,128)
X_train = X_train.astype('float32')/255.0
X_train = X_train.reshape(-1,128,128,3)
print(X_train.shape)
# Out:
# (2609, 128, 128, 3)

# %%
X_val = []
y_val = []

for features, label in validation_data:
    X_val.append(features)
    y_val.append(label)

X_val = np.array(X_val).reshape(-1,128,128)
X_val = X_val.astype('float32')/255.0
X_val = X_val.reshape(-1,128,128,3)
print(X_val.shape)
# Out:
# (325, 128, 128, 3)

# %%
X_test = []
y_test = []

for features, label in testing_data:
    X_test.append(features)
    y_test.append(label)

X_test = np.array(X_test).reshape(-1,128,128)
X_test = X_test.astype('float32')/255.0
X_test = X_test.reshape(-1,128,128,3)
print(X_test.shape)
# Out:
# (330, 128, 128, 3)

# %% [markdown]
# ### Label encoding

# %%
y_train = np.array(y_train)
y_val = np.array(y_val)
y_test = np.array(y_test)

# %%
from keras.utils.np_utils import to_categorical
y_train = to_categorical(y_train, num_classes=4)
y_val = to_categorical(y_val, num_classes=4)
y_test = to_categorical(y_test, num_classes=4)

# %%
print("x_train shape",X_train.shape)
print("x_val shape",X_val.shape)
print("x_test shape",X_test.shape)
print("y_train shape",y_train.shape)
print("y_test shape",y_val.shape)
print("y_test shape",y_test.shape)
# Out:
# x_train shape (2609, 128, 128, 3)
# x_val shape (325, 128, 128, 3)
# x_test shape (330, 128, 128, 3)
# y_train shape (2609, 4)
# y_test shape (325, 4)
# y_test shape (330, 4)

# %% [markdown]
# ## Hyperparameter Tuning

# %%
import tensorflow as tf
from tensorboard.plugins.hparams import api as hp

# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
HP_NUM_UNITS = hp.HParam('num_units', hp.Discrete([512, 1024]))
HP_DROPOUT = hp.HParam('dropout', hp.RealInterval(0.1, 0.2))
HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['rmsprop', 'adamax', 'adam']))

METRIC_ACCURACY = 'accuracy'

with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
    hp.hparams_config(
        hparams=[HP_NUM_UNITS, HP_DROPOUT, HP_OPTIMIZER],
        metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')],
    )

# %% [markdown]
# ### Data Augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator
batch_size = 32

datagen = ImageDataGenerator(
    rotation_range=30,
    zoom_range=0.2,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False
)

# %%
img_id = 1

brain_generator = datagen.flow(X_train[img_id:img_id+1], y_train[img_id:img_id+1], shuffle=False, batch_size=32, seed=1)

plt.figure(figsize=(30,20))
dogs = [next(brain_generator) for i in range(0,5)]
for counter, dog in enumerate(dogs):
    plt.subplot(1,5,counter+1)
    plt.imshow(dog[0][0])

plt.show()

# %%
import itertools
from keras.utils.np_utils import to_categorical 
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, Input
from keras.optimizers import Adam, SGD
from keras.preprocessing.image import ImageDataGenerator

# %%
def train_test_model(hparams):
    model = Sequential([
        Input(shape=(128,128,3)),
        Conv2D(64, (5,5), padding='Same', activation='relu'),
        MaxPooling2D(pool_size=(2,2)),
        Dropout(hparams[HP_DROPOUT]),

        Conv2D(128, (3,3), padding='Same', activation='relu'),
        MaxPooling2D(pool_size=(2,2), strides=(2,2)),
        Dropout(hparams[HP_DROPOUT]),

        Conv2D(128, (3,3), padding='Same', activation='relu'),
        MaxPooling2D(pool_size=(2,2), strides=(2,2)),
        Dropout(hparams[HP_DROPOUT]),

        Conv2D(128, (3,3), padding='Same', activation='relu'),
        MaxPooling2D(pool_size=(2,2), strides=(2,2)),
        Dropout(hparams[HP_DROPOUT]),

        Conv2D(256, (3,3), padding='Same', activation='relu'),
        MaxPooling2D(pool_size=(2,2), strides=(2,2)),
        Dropout(hparams[HP_DROPOUT]),

        Flatten(),

        Dense(hparams[HP_NUM_UNITS], activation='swish'),
        Dropout(hparams[HP_DROPOUT]),
        Dense(4, activation='softmax')
    ])
    
    model.compile(
    optimizer=hparams[HP_OPTIMIZER],
    loss='categorical_crossentropy',
    metrics=['accuracy']
    )

    datagen.fit(X_train)
    history = model.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size), epochs=5, validation_data=(X_val, y_val), steps_per_epoch=X_train.shape[0] // batch_size)
    _, accuracy = model.evaluate(X_val, y_val)
    return accuracy

# %%
def run(run_dir, hparams):
    with tf.summary.create_file_writer(run_dir).as_default():
        hp.hparams(hparams)
        accuracy = train_test_model(hparams)
        tf.summary.scalar(METRIC_ACCURACY, accuracy, step=50)

# %%
session_num = 0

for num_units in HP_NUM_UNITS.domain.values:
    for dropout_rate in (HP_DROPOUT.domain.min_value, HP_DROPOUT.domain.max_value):
        for optimizer in HP_OPTIMIZER.domain.values:
            hparams = {
                HP_NUM_UNITS: num_units,
                HP_DROPOUT: dropout_rate,
                HP_OPTIMIZER: optimizer
            }

            run_name = "run-%d" % session_num
            print('--- Starting trial: %s' % run_name)
            print({h.name: hparams[h] for h in hparams})
            run('logs/hparam_tuning/' + run_name, hparams)
            session_num += 1
# Out:
# --- Starting trial: run-0
# {'num_units': 512, 'dropout': 0.1, 'optimizer': 'adam'}
# Epoch 1/5
# C:\Users\acer\AppData\Local\Temp\ipykernel_5364\630393410.py:38: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size), epochs=5, validation_data=(X_val, y_val), steps_per_epoch=X_train.shape[0] // batch_size)
# 81/81 [==============================] - 49s 598ms/step - loss: 1.3202 - accuracy: 0.3609 - val_loss: 1.2446 - val_accuracy: 0.4154
# Epoch 2/5
# 81/81 [==============================] - 55s 674ms/step - loss: 1.2018 - accuracy: 0.4629 - val_loss: 1.0648 - val_accuracy: 0.4954
# Epoch 3/5
# 81/81 [==============================] - 55s 676ms/step - loss: 1.0769 - accuracy: 0.5266 - val_loss: 0.9878 - val_accuracy: 0.5692
# Epoch 4/5
# ...

# %%
model1 = Sequential(
    [
    Input(shape=(128,128,3)),

    Conv2D(64, (5,5), padding='Same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.1),

    Conv2D(128, (3,3), padding='Same', activation='relu'),
    MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    Dropout(0.1),

    Conv2D(128, (3,3), padding='Same', activation='relu'),
    MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    Dropout(0.1),

    Conv2D(128, (3,3), padding='Same', activation='relu'),
    MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    Dropout(0.1),

    Conv2D(256, (3,3), padding='Same', activation='relu'),
    MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    Dropout(0.1),

    Flatten(),

    Dense(256, activation='relu'),
    Dropout(0.1),
    Dense(4, activation='softmax')
    ]
)

model1.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_80 (Conv2D)          (None, 128, 128, 64)      4864
#
#  max_pooling2d_80 (MaxPoolin  (None, 64, 64, 64)       0
#  g2D)
#
#  dropout_96 (Dropout)        (None, 64, 64, 64)        0
#
#  conv2d_81 (Conv2D)          (None, 64, 64, 128)       73856
#
#  max_pooling2d_81 (MaxPoolin  (None, 32, 32, 128)      0
#  g2D)
#
#  dropout_97 (Dropout)        (None, 32, 32, 128)       0
#
#  conv2d_82 (Conv2D)          (None, 32, 32, 128)       147584
#
#  max_pooling2d_82 (MaxPoolin  (None, 16, 16, 128)      0
#  g2D)
#
#  dropout_98 (Dropout)        (None, 16, 16, 128)       0
#
#  conv2d_83 (Conv2D)          (None, 16, 16, 128)       147584
#
#  max_pooling2d_83 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  dropout_99 (Dropout)        (None, 8, 8, 128)         0
#
# ...

# %%
from keras.optimizers import Adam
Adam(learning_rate=0.00146, name='Adam')
model1.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
epochs = 100
batch_size = 32
datagen = ImageDataGenerator(
    rotation_range=30,
    zoom_range=0,
    width_shift_range=0,
    height_shift_range=0,
    horizontal_flip=True,
    vertical_flip=False
)

# %%
from tensorflow.keras import callbacks

filepath = 'model1.h5'
checkpoint = callbacks.ModelCheckpoint(
    filepath,
    monitor = 'val_accuracy',
    verbose = 1,
    save_best_only = True,
    mode = 'auto'
)

# %%
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)
    
lr_schedule = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose = 1)

# %%
import time

start = time.time()
datagen.fit(X_train)
history1 = model1.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size),
                                epochs=epochs, validation_data=(X_val, y_val),
                                steps_per_epoch=X_train.shape[0] // batch_size,
                                callbacks=[lr_schedule, checkpoint])
stop = time.time()
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 1/100
# C:\Users\acer\AppData\Local\Temp\ipykernel_5364\146044155.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history1 = model1.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size),
# 81/81 [==============================] - ETA: 0s - loss: 1.3769 - accuracy: 0.2992
# Epoch 1: val_accuracy improved from -inf to 0.28000, saving model to model1.h5
# 81/81 [==============================] - 50s 597ms/step - loss: 1.3769 - accuracy: 0.2992 - val_loss: 1.3588 - val_accuracy: 0.2800 - lr: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 2/100
# 81/81 [==============================] - ETA: 0s - loss: 1.2321 - accuracy: 0.4129
# Epoch 2: val_accuracy improved from 0.28000 to 0.46769, saving model to model1.h5
# ...

# %%
print(f"Training time is {stop -start} s")
# Out:
# Training time is 4816.892104387283 s

# %%
acc = history1.history['accuracy']
val_acc = history1.history['val_accuracy']
loss = history1.history['loss']
val_loss = history1.history['val_loss']

epochs = range(len(acc))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = [30,12])
ax1.plot(epochs, acc, 'k',linewidth='3')
ax1.plot(epochs, val_acc, 'grey', linewidth='3')
ax1.set_title("Accuracy")
ax1.legend(['Train Accuracy', 'Validation Accuracy'])

ax2.plot(epochs, loss, 'k',linewidth='3')
ax2.plot(epochs, val_loss, 'grey', linewidth='3')
ax2.set_title("Loss")
ax2.legend(['Train Loss', 'Validation Loss'])

# %%
loss, acc = model1.evaluate(X_train, y_train, verbose=0)
print("Training loss {:.5f} and Training accuracy {:.2f}".format(loss, acc*100))

loss, acc = model1.evaluate(X_val,y_val, verbose = 0)
print("Validation Loss {:.5f} dan Validation Accuracy {:.2f}%".format(loss,acc*100))

loss, acc = model1.evaluate(X_test,y_test,verbose = 0)
print("Testing Loss {:.5f} dan Testing Accuracy {:.2f}%".format(loss,acc*100))
# Out:
# Training loss 0.22969 and Training accuracy 90.84

# %%
loss, acc = model1.evaluate(X_val,y_val, verbose = 0)
print("Validation Loss {:.5f} dan Validation Accuracy {:.2f}%".format(loss,acc*100))
# Out:
# Validation Loss 0.38606 dan Validation Accuracy 85.23%

# %%
loss, acc = model1.evaluate(X_test,y_test,verbose = 0)
print("Testing Loss {:.5f} dan Testing Accuracy {:.2f}%".format(loss,acc*100))
# Out:
# Testing Loss 0.38566 dan Testing Accuracy 86.97%

# %%
import itertools
from sklearn import metrics
from sklearn.metrics import f1_score, recall_score, accuracy_score
from sklearn.metrics import precision_score, confusion_matrix, classification_report

print("Model 1")
pred = model1.predict(X_val)
labels = (pred > 0.5).astype(np.int)

print(classification_report(y_val, labels, target_names=categories))

y_pred = model1.predict(X_val)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_val, axis = 1)

confusion_mtx = confusion_matrix(y_true, y_pred_classes)
print("Model 1")
plot_confusion_matrix(confusion_mtx, classes=categories)
# Out:
# Model 1
# 11/11 [==============================] - 1s 82ms/step
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.76      0.92      0.83        92
# meningioma_tumor       0.97      0.62      0.76        93
#         no_tumor       0.84      0.94      0.89        50
#  pituitary_tumor       0.96      0.96      0.96        90
#
#        micro avg       0.87      0.85      0.86       325
#        macro avg       0.88      0.86      0.86       325
#     weighted avg       0.89      0.85      0.85       325
#      samples avg       0.85      0.85      0.85       325
# ...

# %%
import seaborn as sns

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion Matrix', cmap=plt.cm.BuPu):
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, fmt='g', cmap=cmap)
    plt.title(title)
    tich_marks = np.arange(len(classes))
    plt.xticks(tich_marks, classes, rotation=45)
    plt.yticks(tich_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

        thresh = cm.max() /2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, cm[i, j], horizontalalignment='center', color='white' if cm[i, j] > thresh else "black")
        plt.tight_layout()
        plt.ylabel("True label")
        plt.xlabel("Predicted label")

# %%
y_pred = model1.predict(X_val)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_val, axis = 1)

confusion_mtx = confusion_matrix(y_true, y_pred_classes)
print("Model 1")
plot_confusion_matrix(confusion_mtx, classes=categories)
# Out:
# 11/11 [==============================] - 1s 80ms/step
# Model 1

# %%
model2 = Sequential(
    [
    Input(shape=(128,128,3)),

    Conv2D(64, (5,5), padding='Same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.2),

    Conv2D(128, (3,3), padding='Same', activation='relu'),
    MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    Dropout(0.2),

    Conv2D(128, (3,3), padding='Same', activation='relu'),
    MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    Dropout(0.2),

    Conv2D(128, (3,3), padding='Same', activation='relu'),
    MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    Dropout(0.2),

    Conv2D(256, (3,3), padding='Same', activation='relu'),
    MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    Dropout(0.2),

    Flatten(),

    Dense(1024, activation='relu'),
    Dropout(0.2),
    Dense(4, activation='softmax')
    ]
)

model2.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_85 (Conv2D)          (None, 128, 128, 64)      4864
#
#  max_pooling2d_85 (MaxPoolin  (None, 64, 64, 64)       0
#  g2D)
#
#  dropout_102 (Dropout)       (None, 64, 64, 64)        0
#
#  conv2d_86 (Conv2D)          (None, 64, 64, 128)       73856
#
#  max_pooling2d_86 (MaxPoolin  (None, 32, 32, 128)      0
#  g2D)
#
#  dropout_103 (Dropout)       (None, 32, 32, 128)       0
#
#  conv2d_87 (Conv2D)          (None, 32, 32, 128)       147584
#
#  max_pooling2d_87 (MaxPoolin  (None, 16, 16, 128)      0
#  g2D)
#
#  dropout_104 (Dropout)       (None, 16, 16, 128)       0
#
#  conv2d_88 (Conv2D)          (None, 16, 16, 128)       147584
#
#  max_pooling2d_88 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  dropout_105 (Dropout)       (None, 8, 8, 128)         0
#
# ...

# %%
from keras.optimizers import Adam
Adam(learning_rate=0.00146, name='Adam')
model2.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
epochs = 100
batch_size = 32
datagen = ImageDataGenerator(
    rotation_range=30,
    zoom_range=0,
    width_shift_range=0,
    height_shift_range=0,
    horizontal_flip=True,
    vertical_flip=False
)

# %%
filepath = 'model2.h5'
checkpoint = callbacks.ModelCheckpoint(
    filepath,
    monitor = 'val_accuracy',
    verbose = 1,
    save_best_only = True,
    mode = 'auto'
)

# %%
start = time.time()
datagen.fit(X_train)
history2 = model2.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size),
                                epochs=epochs, validation_data=(X_val, y_val),
                                steps_per_epoch=X_train.shape[0] // batch_size,
                                callbacks=[lr_schedule, checkpoint])
stop = time.time()
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 1/100
# C:\Users\acer\AppData\Local\Temp\ipykernel_5364\1658471342.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history2 = model2.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size),
# 81/81 [==============================] - ETA: 0s - loss: 1.3383 - accuracy: 0.3954
# Epoch 1: val_accuracy improved from -inf to 0.45538, saving model to model2.h5
# 81/81 [==============================] - 37s 444ms/step - loss: 1.3383 - accuracy: 0.3954 - val_loss: 1.2053 - val_accuracy: 0.4554 - lr: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 2/100
# 81/81 [==============================] - ETA: 0s - loss: 1.0732 - accuracy: 0.5169
# Epoch 2: val_accuracy improved from 0.45538 to 0.49846, saving model to model2.h5
# ...

# %%
acc = history2.history['accuracy']
val_acc = history2.history['val_accuracy']
loss = history2.history['loss']
val_loss = history2.history['val_loss']

epochs = range(len(acc))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = [30,12])
ax1.plot(epochs, acc, 'k',linewidth='3')
ax1.plot(epochs, val_acc, 'grey', linewidth='3')
ax1.set_title("Accuracy")
ax1.legend(['Train Accuracy', 'Validation Accuracy'])

ax2.plot(epochs, loss, 'k',linewidth='3')
ax2.plot(epochs, val_loss, 'grey', linewidth='3')
ax2.set_title("Loss")
ax2.legend(['Train Loss', 'Validation Loss'])

# %%
loss, acc = model2.evaluate(X_train, y_train, verbose=0)
print("Training loss {:.5f} and Training accuracy {:.2f}".format(loss, acc*100))

loss, acc = model2.evaluate(X_val,y_val, verbose = 0)
print("Validation Loss {:.5f} dan Validation Accuracy {:.2f}%".format(loss,acc*100))

loss, acc = model2.evaluate(X_test,y_test,verbose = 0)
print("Testing Loss {:.5f} dan Testing Accuracy {:.2f}%".format(loss,acc*100))
# Out:
# Training loss 0.12035 and Training accuracy 95.67
# Validation Loss 0.25641 dan Validation Accuracy 92.92%
# Testing Loss 0.31136 dan Testing Accuracy 89.70%

# %%
model3 = Sequential(
    [
     Input(shape=(128,128,3)),

     Conv2D(64, (5,5),padding = 'Same', activation = 'relu'),
     MaxPooling2D(pool_size = (2,2)),
     Dropout(0.2),

     Conv2D(128, (3,3),padding = 'Same', activation = 'relu'),
     MaxPooling2D(pool_size = (2,2), strides=(2,2)),
     Dropout(0.2),

     Conv2D(128, (3,3),padding = 'Same', activation = 'relu'),
     MaxPooling2D(pool_size = (2,2), strides=(2,2)),
     Dropout(0.2),

     Conv2D(128, (3,3),padding = 'Same', activation = 'relu'),
     MaxPooling2D(pool_size = (2,2), strides=(2,2)),
     Dropout(0.2),

     Conv2D(256, (3,3),padding = 'Same', activation = 'relu'),
     MaxPooling2D(pool_size = (2,2), strides=(2,2)),
     Dropout(0.2),  

     Flatten(),
     
     Dense(1024, activation = 'relu'),
     Dropout(0.5),
     Dense(4, activation='softmax')
    ]
)

model3.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_90 (Conv2D)          (None, 128, 128, 64)      4864
#
#  max_pooling2d_90 (MaxPoolin  (None, 64, 64, 64)       0
#  g2D)
#
#  dropout_108 (Dropout)       (None, 64, 64, 64)        0
#
#  conv2d_91 (Conv2D)          (None, 64, 64, 128)       73856
#
#  max_pooling2d_91 (MaxPoolin  (None, 32, 32, 128)      0
#  g2D)
#
#  dropout_109 (Dropout)       (None, 32, 32, 128)       0
#
#  conv2d_92 (Conv2D)          (None, 32, 32, 128)       147584
#
#  max_pooling2d_92 (MaxPoolin  (None, 16, 16, 128)      0
#  g2D)
#
#  dropout_110 (Dropout)       (None, 16, 16, 128)       0
#
#  conv2d_93 (Conv2D)          (None, 16, 16, 128)       147584
#
#  max_pooling2d_93 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  dropout_111 (Dropout)       (None, 8, 8, 128)         0
#
# ...

# %%
from keras.optimizers import Adamax

Adamax(learning_rate=0.00146, name='Adamax')
model3.compile(optimizer = 'Adamax',loss = 'categorical_crossentropy',metrics = ['accuracy'])

# %%
epochs = 100  
batch_size = 32

datagen = ImageDataGenerator(
        rotation_range=30,
        zoom_range = 0,
        width_shift_range=0,  
        height_shift_range=0,  
        horizontal_flip=True,  
        vertical_flip=False)

# %%
from tensorflow.keras import callbacks

checkpoint = callbacks.ModelCheckpoint(
                                       filepath,
                                       monitor='val_accuracy',
                                       verbose=1,
                                       save_best_only=True,
                                       mode='auto',
                                       )
earlystop = callbacks.EarlyStopping(monitor='val_loss',
                                    mode='auto',
                                    patience=4,
                                    restore_best_weights=True)

# %%
import time

start = time.time()
datagen.fit(X_train)
history1 = model3.fit_generator(datagen.flow(X_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (X_val,y_val),
                              steps_per_epoch = X_train.shape[0] // batch_size,
                              callbacks=[checkpoint])
stop = time.time()
# Out:
# Epoch 1/100
# C:\Users\acer\AppData\Local\Temp\ipykernel_5364\1517907161.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history1 = model3.fit_generator(datagen.flow(X_train,y_train, batch_size=batch_size),
# 81/81 [==============================] - ETA: 0s - loss: 1.3608 - accuracy: 0.3225
# Epoch 1: val_accuracy improved from -inf to 0.39077, saving model to model2.h5
# 81/81 [==============================] - 47s 550ms/step - loss: 1.3608 - accuracy: 0.3225 - val_loss: 1.2971 - val_accuracy: 0.3908
# Epoch 2/100
# 81/81 [==============================] - ETA: 0s - loss: 1.1986 - accuracy: 0.4711
# Epoch 2: val_accuracy improved from 0.39077 to 0.49538, saving model to model2.h5
# 81/81 [==============================] - 43s 535ms/step - loss: 1.1986 - accuracy: 0.4711 - val_loss: 1.0947 - val_accuracy: 0.4954
# Epoch 3/100
# ...

# %%
loss, acc = model3.evaluate(X_train, y_train, verbose=0)
print("Training loss {:.5f} and Training accuracy {:.2f}".format(loss, acc*100))

loss, acc = model3.evaluate(X_val,y_val, verbose = 0)
print("Validation Loss {:.5f} dan Validation Accuracy {:.2f}%".format(loss,acc*100))

loss, acc = model3.evaluate(X_test,y_test,verbose = 0)
print("Testing Loss {:.5f} dan Testing Accuracy {:.2f}%".format(loss,acc*100))
# Out:
# Training loss 0.00803 and Training accuracy 99.77
# Validation Loss 0.21414 dan Validation Accuracy 94.77%
# Testing Loss 0.23130 dan Testing Accuracy 95.45%

# %%
loss, acc = model3.evaluate(X_train, y_train, verbose=0)
print("Training loss {:.5f} and Training accuracy {:.2f}".format(loss, acc*100))

loss, acc = model3.evaluate(X_val,y_val, verbose = 0)
print("Validation Loss {:.5f} dan Validation Accuracy {:.2f}%".format(loss,acc*100))

loss, acc = model3.evaluate(X_test,y_test,verbose = 0)
print("Testing Loss {:.5f} dan Testing Accuracy {:.2f}%".format(loss,acc*100))
# Out:
# Training loss 0.00803 and Training accuracy 99.77
# Validation Loss 0.21414 dan Validation Accuracy 94.77%
# Testing Loss 0.23130 dan Testing Accuracy 95.45%

# %%
model4 = Sequential(
    [
     Input(shape=(128,128,3)),

     Conv2D(64, (5,5),padding = 'Same', activation = 'relu'),
     MaxPooling2D(pool_size = (2,2)),
     Dropout(0.2),

     Conv2D(128, (3,3),padding = 'Same', activation = 'relu'),
     MaxPooling2D(pool_size = (2,2), strides=(2,2)),
     Dropout(0.2),

     Conv2D(128, (3,3),padding = 'Same', activation = 'relu'),
     MaxPooling2D(pool_size = (2,2), strides=(2,2)),
     Dropout(0.2),

     Conv2D(128, (3,3),padding = 'Same', activation = 'relu'),
     MaxPooling2D(pool_size = (2,2), strides=(2,2)),
     Dropout(0.2),

     Conv2D(256, (3,3),padding = 'Same', activation = 'relu'),
     MaxPooling2D(pool_size = (2,2), strides=(2,2)),
     Dropout(0.2),  

     Flatten(),
     
     Dense(512, activation = 'relu'),
     Dropout(0.5),
     Dense(4, activation='softmax')
    ]
)

model4.summary()
# Out:
# Model: "sequential_35"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_175 (Conv2D)         (None, 128, 128, 64)      4864
#
#  max_pooling2d_175 (MaxPooli  (None, 64, 64, 64)       0
#  ng2D)
#
#  dropout_210 (Dropout)       (None, 64, 64, 64)        0
#
#  conv2d_176 (Conv2D)         (None, 64, 64, 128)       73856
#
#  max_pooling2d_176 (MaxPooli  (None, 32, 32, 128)      0
#  ng2D)
#
#  dropout_211 (Dropout)       (None, 32, 32, 128)       0
#
#  conv2d_177 (Conv2D)         (None, 32, 32, 128)       147584
#
#  max_pooling2d_177 (MaxPooli  (None, 16, 16, 128)      0
#  ng2D)
#
#  dropout_212 (Dropout)       (None, 16, 16, 128)       0
#
#  conv2d_178 (Conv2D)         (None, 16, 16, 128)       147584
#
#  max_pooling2d_178 (MaxPooli  (None, 8, 8, 128)        0
#  ng2D)
#
#  dropout_213 (Dropout)       (None, 8, 8, 128)         0
#
# ...

# %%
from keras.optimizers import RMSprop

RMSprop(learning_rate=0.00146, name='RMSprop')
model4.compile(optimizer = 'RMSprop',loss = 'categorical_crossentropy',metrics = ['accuracy'])

# %%
epochs = 100  
batch_size = 32
datagen = ImageDataGenerator(
        rotation_range=0,
        zoom_range = 0,
        width_shift_range=0,  
        height_shift_range=0,  
        horizontal_flip=True,  
        vertical_flip=False)

checkpoint = callbacks.ModelCheckpoint(
                                       filepath,
                                       monitor='val_accuracy',
                                       verbose=1,
                                       save_best_only=True,
                                       mode='auto',
                                       )
earlystop = callbacks.EarlyStopping(monitor='val_loss',
                                    mode='auto',
                                    patience=4,
                                    restore_best_weights=True)

# %%
start = time.time()
datagen.fit(X_train)
history2 = model4.fit_generator(datagen.flow(X_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (X_val,y_val),
                              steps_per_epoch = X_train.shape[0] // batch_size,
                              callbacks=[checkpoint])
stop = time.time()

loss, acc = model4.evaluate(X_train, y_train, verbose=0)
print("Training loss {:.5f} and Training accuracy {:.2f}".format(loss, acc*100))

loss, acc = model4.evaluate(X_val,y_val, verbose = 0)
print("Validation Loss {:.5f} dan Validation Accuracy {:.2f}%".format(loss,acc*100))

loss, acc = model4.evaluate(X_test,y_test,verbose = 0)
print("Testing Loss {:.5f} dan Testing Accuracy {:.2f}%".format(loss,acc*100))
# Out:
# Epoch 1/100
# C:\Users\acer\AppData\Local\Temp\ipykernel_5364\1526117350.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history2 = model4.fit_generator(datagen.flow(X_train,y_train, batch_size=batch_size),
# 81/81 [==============================] - ETA: 0s - loss: 1.3913 - accuracy: 0.3007
# Epoch 1: val_accuracy improved from -inf to 0.28308, saving model to model2.h5
# 81/81 [==============================] - 37s 452ms/step - loss: 1.3913 - accuracy: 0.3007 - val_loss: 1.3341 - val_accuracy: 0.2831
# Epoch 2/100
# 81/81 [==============================] - ETA: 0s - loss: 1.2292 - accuracy: 0.4338
# Epoch 2: val_accuracy improved from 0.28308 to 0.50769, saving model to model2.h5
# 81/81 [==============================] - 40s 493ms/step - loss: 1.2292 - accuracy: 0.4338 - val_loss: 1.0580 - val_accuracy: 0.5077
# Epoch 3/100
# ...

# %%
acc = history2.history['accuracy']
val_acc = history2.history['val_accuracy']
loss = history2.history['loss']
val_loss = history2.history['val_loss']

epochs = range(len(acc))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = [30,12])
ax1.plot(epochs, acc, 'k',linewidth='3')
ax1.plot(epochs, val_acc, 'grey', linewidth='3')
ax1.set_title("Accuracy")
ax1.legend(['Train Accuracy', 'Validation Accuracy'])

ax2.plot(epochs, loss, 'k',linewidth='3')
ax2.plot(epochs, val_loss, 'grey', linewidth='3')
ax2.set_title("Loss")
ax2.legend(['Train Loss', 'Validation Loss'])

# %%
import itertools
from sklearn import metrics
from sklearn.metrics import f1_score, recall_score, accuracy_score
from sklearn.metrics import precision_score, confusion_matrix, classification_report

print("Model 4")
pred = model4.predict(X_val)
labels = (pred > 0.5).astype(np.int)

print(classification_report(y_val, labels, target_names=categories))
# Out:
# Model 4
# 11/11 [==============================] - 1s 85ms/step
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.99      0.96      0.97        92
# meningioma_tumor       0.98      0.98      0.98        93
#         no_tumor       0.96      1.00      0.98        50
#  pituitary_tumor       0.99      1.00      0.99        90
#
#        micro avg       0.98      0.98      0.98       325
#        macro avg       0.98      0.98      0.98       325
#     weighted avg       0.98      0.98      0.98       325
#      samples avg       0.98      0.98      0.98       325
# ...

# %%
y_pred = model4.predict(X_val)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_val, axis = 1)

confusion_mtx = confusion_matrix(y_true, y_pred_classes)
print("Model 1")
plot_confusion_matrix(confusion_mtx, classes=categories)
# Out:
# 11/11 [==============================] - 1s 90ms/step
# Model 1

# %%
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier

# %%
input_dim = X_train.shape[1]
num_classes = 4

# let's create a function that creates the model (required for KerasClassifier) 
# while accepting the hyperparameters we want to tune 
# we also pass some default values such as optimizer='rmsprop'
def create_model_2(optimizer='rmsprop', init='glorot_uniform'):
    model = Sequential()
    model.add(Input(shape=(128,128,3))),

    model.add(Conv2D(64, (5,5), padding='Same', activation='relu')),
    model.add(MaxPooling2D(pool_size=(2,2))),
    model.add(Dropout(0.2)),

    model.add(Conv2D(128, (3,3), padding='Same', activation='relu')),
    model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2))),
    model.add(Dropout(0.2)),

    model.add(Conv2D(128, (3,3), padding='Same', activation='relu')),
    model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2))),
    model.add(Dropout(0.2)),

    model.add(Conv2D(128, (3,3), padding='Same', activation='relu')),
    model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2))),
    model.add(Dropout(0.2)),

    model.add(Conv2D(256, (3,3), padding='Same', activation='relu')),
    model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2))),
    model.add(Dropout(0.2)),

    model.add(Flatten()),

    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(num_classes, kernel_initializer=init, activation=tf.nn.softmax))

    # compile model
    model.compile(loss='categorical_crossentropy', 
                  optimizer=optimizer, 
                  metrics=['accuracy'])

    return model

# %%
seed = 7
np.random.seed(seed)

# create the sklearn model for the network
model_init_batch_epoch_CV = KerasClassifier(build_fn=create_model_2, verbose=1)

# we choose the initializers that came at the top in our previous cross-validation!!
init_mode = ['glorot_uniform', 'uniform'] 
batches = [128, 512]
epochs = [10, 20]

# grid search for initializer, batch size and number of epochs
param_grid = dict(epochs=epochs, batch_size=batches, init=init_mode)
grid = GridSearchCV(estimator=model_init_batch_epoch_CV, 
                    param_grid=param_grid,
                    cv=3)
grid_result = grid.fit(X_train, y_train)
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_5364\555341727.py:5: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model_init_batch_epoch_CV = KerasClassifier(build_fn=create_model_2, verbose=1)
# Epoch 1/10
# 14/14 [==============================] - 24s 2s/step - loss: 1.4016 - accuracy: 0.3824
# Epoch 2/10
# 14/14 [==============================] - 26s 2s/step - loss: 1.0784 - accuracy: 0.4589
# Epoch 3/10
# 14/14 [==============================] - 27s 2s/step - loss: 1.0482 - accuracy: 0.5078
# Epoch 4/10
# 14/14 [==============================] - 27s 2s/step - loss: 0.9876 - accuracy: 0.5952
# Epoch 5/10
# 14/14 [==============================] - 27s 2s/step - loss: 0.8693 - accuracy: 0.6394
# Epoch 6/10
# 14/14 [==============================] - 27s 2s/step - loss: 0.8554 - accuracy: 0.6619
# Epoch 7/10
# ...

# %%
print(f'Best Accuracy for {grid_result.best_score_:.4} using {grid_result.best_params_}')
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print(f'mean={mean:.4}, std={stdev:.4} using {param}')
